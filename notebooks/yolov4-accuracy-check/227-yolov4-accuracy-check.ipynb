# %% [markdown]
# # YOLOV4

# %%
# !omz_downloader --name yolo-v4-tf -o ./
# Out:
# ################|| Downloading yolo-v4-tf ||################
#
# ========== Downloading public/yolo-v4-tf/yolov4.weights
# ... 100%, 251677 KB, 8634 KB/s, 29 seconds passed
#
# ========== Downloading public/yolo-v4-tf/keras-YOLOv3-model-set/tools/model_converter/convert.py
# ... 100%, 16 KB, 40878 KB/s, 0 seconds passed
#
# ========== Downloading public/yolo-v4-tf/keras-YOLOv3-model-set/yolo4/models/layers.py
# ... 100%, 15 KB, 89081 KB/s, 0 seconds passed
#
# ========== Downloading public/yolo-v4-tf/keras-YOLOv3-model-set/cfg/yolov4.cfg
# ... 100%, 11 KB, 60627 KB/s, 0 seconds passed
#
# ========== Replacing text in public/yolo-v4-tf/keras-YOLOv3-model-set/yolo4/models/layers.py
# ========== Replacing text in public/yolo-v4-tf/keras-YOLOv3-model-set/yolo4/models/layers.py

# %%
# !omz_converter --name yolo-v4-tf -d ./ -o ./yolov4
# Out:
# ========== Running pre-convert script for yolo-v4-tf
# Pre-convert command: /home/ease/miniconda3/envs/openvino/bin/python -- /home/ease/miniconda3/envs/openvino/lib/python3.8/site-packages/openvino/model_zoo/models/public/yolo-v4-tf/pre-convert.py -- public/yolo-v4-tf yolov4/public/yolo-v4-tf
#
# 2022-12-26 10:26:59.986829: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/IntelPTAT/Target
# 2022-12-26 10:26:59.986866: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Loading weights.
# Weights Header:  0 2 5 [32032000]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn mish (3, 3, 3, 32)
# ...

# %%
# !omz_converter --name yolo-v4-tf -d ./ -o ./yolov4 --add_mo_arg '--input_shape=[1, 640, 640, 3]'
# Out:
# ========== Running pre-convert script for yolo-v4-tf
# Pre-convert command: /home/ease/miniconda3/envs/openvino/bin/python -- /home/ease/miniconda3/envs/openvino/lib/python3.8/site-packages/openvino/model_zoo/models/public/yolo-v4-tf/pre-convert.py -- public/yolo-v4-tf yolov4/public/yolo-v4-tf
#
# 2022-12-26 10:39:23.218157: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/IntelPTAT/Target
# 2022-12-26 10:39:23.218180: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Loading weights.
# Weights Header:  0 2 5 [32032000]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn mish (3, 3, 3, 32)
# ...

# %%
# !accuracy_check -c yolo-v4-tf-int8.yml -m ./yolov4/public/yolo-v4-tf/FP32
# Out:
# Processing info:
# model: yolo_v4_tf
# launcher: openvino
# device: CPU
# dataset: ms_coco_detection_80_class_without_background
# OpenCV version: 4.5.5
# Annotation conversion for ms_coco_detection_80_class_without_background dataset has been started
# Parameters to be used for conversion:
# converter: mscoco_detection
# annotation_file: /home/ease/repos/openvino_notebooks/notebooks/227-yolov4-accuracy-check/coco_dataset/annotations/instances_val2017.json
# Total annotations size: 5000
# 100 / 5000 processed in 0.714s
# 200 / 5000 processed in 0.727s
# 300 / 5000 processed in 0.711s
# 400 / 5000 processed in 0.743s
# 500 / 5000 processed in 0.747s
# 600 / 5000 processed in 0.731s
# 700 / 5000 processed in 0.729s
# 800 / 5000 processed in 0.771s
# 900 / 5000 processed in 0.746s
# 1000 / 5000 processed in 0.763s
# 1100 / 5000 processed in 0.721s
# 1200 / 5000 processed in 0.752s
# 1300 / 5000 processed in 0.782s
# 1400 / 5000 processed in 0.750s
# 1500 / 5000 processed in 0.716s
# ...

# %%
# !accuracy_check -c yolo-v4-tf-int8.yml -m ./yolov4/public/yolo-v4-tf/FP16

# %%
# !pot -c yolo-v4-tf-int8.json -e
# Out:
# /home/ease/miniconda3/envs/openvino/lib/python3.8/site-packages/openvino/offline_transformations/__init__.py:10: FutureWarning: The module is private and following namespace `offline_transformations` will be removed in the future, use `openvino.runtime.passes` instead!
#   warnings.warn(
# INFO:openvino.tools.pot.app.run:Output log dir: ./results/yolo-v4-tf_DefaultQuantization/2022-12-26_12-54-02
# INFO:openvino.tools.pot.app.run:Creating pipeline:
#  Algorithm: DefaultQuantization
#  Parameters:
# 	preset                     : performance
# 	stat_subset_size           : 300
# 	target_device              : ANY
# 	model_type                 : None
# 	dump_intermediate_model    : False
# 	inplace_statistics         : True
# 	exec_log_dir               : ./results/yolo-v4-tf_DefaultQuantization/2022-12-26_12-54-02
# ...
# IE version: 2022.3.0-8831-4f0b846d1a5
# Loaded CPU plugin version:
#     CPU - openvino_intel_cpu_plugin: 2022.3.2022.3.0-8831-4f0b846d1a5
# ...

# %%
# %mkdir /home/openvino/openvino_models/public/yolo-v4-tf/FP16-INT8/
# %cp -ar results/yolo-v4-tf_DefaultQuantization/2*/optimized/* /home/openvino/openvino_models/public/yolo-v4-tf/FP16-INT8/

# %% [markdown]
# ## Benchmark

# %%
# Inference FP32 model (OpenVINO IR)
# !benchmark_app -m ./yolov4/public/yolo-v4-tf/FP32/yolo-v4-tf.xml -d CPU -api async
# Out:
# [Step 1/11] Parsing and validating input arguments
# [ INFO ] Parsing input parameters
# [Step 2/11] Loading OpenVINO Runtime
# [ INFO ] OpenVINO:
# [ INFO ] Build ................................. 2022.3.0-8831-4f0b846d1a5
# [ INFO ]
# [ INFO ] Device info:
# [ INFO ] CPU
# [ INFO ] Build ................................. 2022.3.0-8831-4f0b846d1a5
# [ INFO ]
# [ INFO ]
# [Step 3/11] Setting device configuration
# [ WARNING ] Performance hint was not explicitly specified in command line. Device(CPU) performance hint will be set to THROUGHPUT.
# [Step 4/11] Reading model files
# [ INFO ] Loading model files
# [ INFO ] Read model took 225.44 ms
# [ INFO ] Original model I/O parameters:
# [ INFO ] Model inputs:
# [ INFO ]     image_input:0 , image_input , Func/StatefulPartitionedCall/input/_0:0 (node: image_input) : f32 / [N,H,W,C] / [1,640,640,3]
# [ INFO ] Model outputs:
# ...

# %%
# Inference FP32 model (OpenVINO IR)
# !benchmark_app -m ./yolov4/public/yolo-v4-tf/FP32/yolo-v4-tf.xml -d GPU -api async
# Out:
# [Step 1/11] Parsing and validating input arguments
# [ INFO ] Parsing input parameters
# [Step 2/11] Loading OpenVINO Runtime
# [ INFO ] OpenVINO:
# [ INFO ] Build ................................. 2022.3.0-8831-4f0b846d1a5
# [ INFO ]
# [ INFO ] Device info:
# [ INFO ] GPU
# [ INFO ] Build ................................. 2022.3.0-8831-4f0b846d1a5
# [ INFO ]
# [ INFO ]
# [Step 3/11] Setting device configuration
# [ WARNING ] Performance hint was not explicitly specified in command line. Device(GPU) performance hint will be set to THROUGHPUT.
# [Step 4/11] Reading model files
# [ INFO ] Loading model files
# [ INFO ] Read model took 134.61 ms
# [ INFO ] Original model I/O parameters:
# [ INFO ] Model inputs:
# [ INFO ]     Func/StatefulPartitionedCall/input/_0:0 , image_input , image_input:0 (node: image_input) : f32 / [N,H,W,C] / [1,640,640,3]
# [ INFO ] Model outputs:
# ...

# %%
# Inference FP16 model (OpenVINO IR)
# !benchmark_app -m ./yolov4/public/yolo-v4-tf/FP16/yolo-v4-tf.xml -d CPU -api async
# Out:
# [Step 1/11] Parsing and validating input arguments
# [ INFO ] Parsing input parameters
# [Step 2/11] Loading OpenVINO Runtime
# [ INFO ] OpenVINO:
# [ INFO ] Build ................................. 2022.3.0-8831-4f0b846d1a5
# [ INFO ]
# [ INFO ] Device info:
# [ INFO ] CPU
# [ INFO ] Build ................................. 2022.3.0-8831-4f0b846d1a5
# [ INFO ]
# [ INFO ]
# [Step 3/11] Setting device configuration
# [ WARNING ] Performance hint was not explicitly specified in command line. Device(CPU) performance hint will be set to THROUGHPUT.
# [Step 4/11] Reading model files
# [ INFO ] Loading model files
# [ INFO ] Read model took 142.46 ms
# [ INFO ] Original model I/O parameters:
# [ INFO ] Model inputs:
# [ INFO ]     image_input:0 , Func/StatefulPartitionedCall/input/_0:0 , image_input (node: image_input) : f32 / [N,H,W,C] / [1,640,640,3]
# [ INFO ] Model outputs:
# ...

# %%
# Inference FP16 model (OpenVINO IR)
# !benchmark_app -m ./yolov4/public/yolo-v4-tf/FP16/yolo-v4-tf.xml -d GPU -api async
# Out:
# [Step 1/11] Parsing and validating input arguments
# [ INFO ] Parsing input parameters
# [Step 2/11] Loading OpenVINO Runtime
# [ INFO ] OpenVINO:
# [ INFO ] Build ................................. 2022.3.0-8831-4f0b846d1a5
# [ INFO ]
# [ INFO ] Device info:
# [ INFO ] GPU
# [ INFO ] Build ................................. 2022.3.0-8831-4f0b846d1a5
# [ INFO ]
# [ INFO ]
# [Step 3/11] Setting device configuration
# [ WARNING ] Performance hint was not explicitly specified in command line. Device(GPU) performance hint will be set to THROUGHPUT.
# [Step 4/11] Reading model files
# [ INFO ] Loading model files
# [ INFO ] Read model took 83.58 ms
# [ INFO ] Original model I/O parameters:
# [ INFO ] Model inputs:
# [ INFO ]     image_input , Func/StatefulPartitionedCall/input/_0:0 , image_input:0 (node: image_input) : f32 / [N,H,W,C] / [1,640,640,3]
# [ INFO ] Model outputs:
# ...

# %%
# Inference INT8 model (OpenVINO IR)
# !benchmark_app -m ./yolov4/public/yolo-v4-tf/FP16-INT8/optimized/yolo-v4-tf.xml -d CPU -api async
# Out:
# [Step 1/11] Parsing and validating input arguments
# [ INFO ] Parsing input parameters
# [Step 2/11] Loading OpenVINO Runtime
# [ INFO ] OpenVINO:
# [ INFO ] Build ................................. 2022.3.0-8831-4f0b846d1a5
# [ INFO ]
# [ INFO ] Device info:
# [ INFO ] CPU
# [ INFO ] Build ................................. 2022.3.0-8831-4f0b846d1a5
# [ INFO ]
# [ INFO ]
# [Step 3/11] Setting device configuration
# [ WARNING ] Performance hint was not explicitly specified in command line. Device(CPU) performance hint will be set to THROUGHPUT.
# [Step 4/11] Reading model files
# [ INFO ] Loading model files
# [ INFO ] Read model took 60.51 ms
# [ INFO ] Original model I/O parameters:
# [ INFO ] Model inputs:
# [ INFO ]     Func/StatefulPartitionedCall/input/_0:0 , image_input:0 , image_input (node: image_input) : f32 / [N,H,W,C] / [1,640,640,3]
# [ INFO ] Model outputs:
# ...

# %%
# Inference INT8 model (OpenVINO IR)
# !benchmark_app -m ./yolov4/public/yolo-v4-tf/FP16-INT8/optimized/yolo-v4-tf.xml -d GPU -api async
# Out:
# [Step 1/11] Parsing and validating input arguments
# [ INFO ] Parsing input parameters
# [Step 2/11] Loading OpenVINO Runtime
# [ INFO ] OpenVINO:
# [ INFO ] Build ................................. 2022.3.0-8831-4f0b846d1a5
# [ INFO ]
# [ INFO ] Device info:
# [ INFO ] GPU
# [ INFO ] Build ................................. 2022.3.0-8831-4f0b846d1a5
# [ INFO ]
# [ INFO ]
# [Step 3/11] Setting device configuration
# [ WARNING ] Performance hint was not explicitly specified in command line. Device(GPU) performance hint will be set to THROUGHPUT.
# [Step 4/11] Reading model files
# [ INFO ] Loading model files
# [ INFO ] Read model took 59.85 ms
# [ INFO ] Original model I/O parameters:
# [ INFO ] Model inputs:
# [ INFO ]     image_input:0 , image_input , Func/StatefulPartitionedCall/input/_0:0 (node: image_input) : f32 / [N,H,W,C] / [1,640,640,3]
# [ INFO ] Model outputs:
# ...
